# %%
# !apt update
# !apt install -y graphviz
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Release [696 B]
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Release.gpg [836 B]
# Hit:7 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:8 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [551 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [837 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [1844 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [1417 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [30.1 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [833 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1118 kB]m
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [33.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [899 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [22.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [50.8 kB]33m
# Fetched 7974 kB in 17s (461 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 32 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation libann0
#   libbsd0 libcairo2 libcdt5 libcgraph6 libdatrie1 libfontconfig1 libfribidi0
#   libgd3 libgraphite2-3 libgts-0.7-5 libgts-bin libgvc6 libgvpr2 libharfbuzz0b
#   libice6 libjbig0 liblab-gamut1 libltdl7 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpathplan4 libpixman-1-0 libsm6 libthai-data libthai0
#   libtiff5 libwebp6 libx11-6 libx11-data libxau6 libxaw7 libxcb-render0
#   libxcb-shm0 libxcb1 libxdmcp6 libxext6 libxmu6 libxpm4 libxrender1 libxt6
#   ucf x11-common
# Suggested packages:
#   gsfonts graphviz-doc libgd-tools
# The following NEW packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation graphviz
#   libann0 libbsd0 libcairo2 libcdt5 libcgraph6 libdatrie1 libfontconfig1
#   libfribidi0 libgd3 libgraphite2-3 libgts-0.7-5 libgts-bin libgvc6 libgvpr2
#   libharfbuzz0b libice6 libjbig0 liblab-gamut1 libltdl7 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4 libpixman-1-0 libsm6
#   libthai-data libthai0 libtiff5 libwebp6 libx11-6 libx11-data libxau6 libxaw7
#   libxcb-render0 libxcb-shm0 libxcb1 libxdmcp6 libxext6 libxmu6 libxpm4
#   libxrender1 libxt6 ucf x11-common
# 0 upgraded, 49 newly installed, 0 to remove and 32 not upgraded.
# Need to get 7687 kB of archives.
# After this operation, 27.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libbsd0 amd64 0.10.0-1 [45.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libfribidi0 amd64 1.0.8-2 [23.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 ucf all 3.0038+nmu1 [51.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libxau6 amd64 1:1.0.9-0ubuntu1 [7488 B]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdmcp6 amd64 1:1.1.3-0ubuntu1 [10.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb1 amd64 1.14-2 [44.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-data all 2:1.6.9-2ubuntu1.2 [113 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-6 amd64 2:1.6.9-2ubuntu1.2 [575 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libxext6 amd64 2:1.3.4-0ubuntu1 [29.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-dejavu-core all 2.37-1 [1041 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-liberation all 1:1.07.4-11 [822 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 fontconfig-config all 2.13.1-2ubuntu3 [28.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontconfig1 amd64 2.13.1-2ubuntu3 [114 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 fontconfig amd64 2.13.1-2ubuntu3 [171 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/universe amd64 libann0 amd64 1.1.2+doc-7build1 [26.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcdt5 amd64 2.42.2-3build2 [18.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcgraph6 amd64 2.42.2-3build2 [41.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 libjbig0 amd64 2.1-3.1build1 [26.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwebp6 amd64 0.6.1-2ubuntu0.20.04.1 [185 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtiff5 amd64 4.1.0+git191117-2ubuntu0.20.04.2 [162 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 libxpm4 amd64 1:3.5.12-1 [34.0 kB]3m
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgd3 amd64 2.2.5-5.2ubuntu2.1 [118 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgts-0.7-5 amd64 0.7.6+darcs121130-4 [150 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libpixman-1-0 amd64 0.38.4-0ubuntu1 [227 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-render0 amd64 1.14-2 [14.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0 amd64 1.14-2 [5584 B]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrender1 amd64 1:0.9.10-1 [18.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo2 amd64 1.16.0-4ubuntu1 [583 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 libltdl7 amd64 2.4.6-14 [38.5 kB]33m
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libgraphite2-3 amd64 1.3.13-11build1 [73.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 libharfbuzz0b amd64 2.6.4-1ubuntu4 [391 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libthai-data all 0.1.28-3 [134 kB]3m
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 libdatrie1 amd64 0.2.12-3 [18.7 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 libthai0 amd64 0.1.28-3 [18.1 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal/main amd64 libpango-1.0-0 amd64 1.44.7-2ubuntu4 [162 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangoft2-1.0-0 amd64 1.44.7-2ubuntu4 [34.9 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangocairo-1.0-0 amd64 1.44.7-2ubuntu4 [24.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpathplan4 amd64 2.42.2-3build2 [21.9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgvc6 amd64 2.42.2-3build2 [647 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgvpr2 amd64 2.42.2-3build2 [167 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/universe amd64 liblab-gamut1 amd64 2.42.2-3build2 [177 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-common all 1:7.7+19ubuntu14 [22.3 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 libice6 amd64 2:1.0.10-0ubuntu1 [41.0 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/main amd64 libsm6 amd64 2:1.2.3-1 [16.1 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 libxt6 amd64 1:1.1.5-1 [160 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmu6 amd64 2:1.1.3-0ubuntu1 [45.8 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/main amd64 libxaw7 amd64 2:1.0.13-1 [173 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/universe amd64 graphviz amd64 2.42.2-3build2 [590 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgts-bin amd64 0.7.6+darcs121130-4 [41.3 kB]m
# Fetched 7687 kB in 31s (251 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libbsd0:amd64.
# (Reading database ... 20631 files and directories currently installed.)
# Preparing to unpack .../00-libbsd0_0.10.0-1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libbsd0:amd64 (0.10.0-1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libfribidi0:amd64.
# Preparing to unpack .../01-libfribidi0_1.0.8-2_amd64.deb ...
# Unpacking libfribidi0:amd64 (1.0.8-2) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package ucf.
# Preparing to unpack .../02-ucf_3.0038+nmu1_all.deb ...
# Moving old data out of the way
# Unpacking ucf (3.0038+nmu1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libxau6:amd64.
# Preparing to unpack .../03-libxau6_1%3a1.0.9-0ubuntu1_amd64.deb ...
# Unpacking libxau6:amd64 (1:1.0.9-0ubuntu1) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package libxdmcp6:amd64.
# Preparing to unpack .../04-libxdmcp6_1%3a1.1.3-0ubuntu1_amd64.deb ...
# Unpacking libxdmcp6:amd64 (1:1.1.3-0ubuntu1) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libxcb1:amd64.
# Preparing to unpack .../05-libxcb1_1.14-2_amd64.deb ...
# Unpacking libxcb1:amd64 (1.14-2) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libx11-data.
# Preparing to unpack .../06-libx11-data_2%3a1.6.9-2ubuntu1.2_all.deb ...
# Unpacking libx11-data (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libx11-6:amd64.
# Preparing to unpack .../07-libx11-6_2%3a1.6.9-2ubuntu1.2_amd64.deb ...
# Unpacking libx11-6:amd64 (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package libxext6:amd64.
# Preparing to unpack .../08-libxext6_2%3a1.3.4-0ubuntu1_amd64.deb ...
# Unpacking libxext6:amd64 (2:1.3.4-0ubuntu1) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../09-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package fonts-liberation.
# Preparing to unpack .../10-fonts-liberation_1%3a1.07.4-11_all.deb ...
# Unpacking fonts-liberation (1:1.07.4-11) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package fontconfig-config.
# Preparing to unpack .../11-fontconfig-config_2.13.1-2ubuntu3_all.deb ...
# Unpacking fontconfig-config (2.13.1-2ubuntu3) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package libfontconfig1:amd64.
# Preparing to unpack .../12-libfontconfig1_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking libfontconfig1:amd64 (2.13.1-2ubuntu3) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package fontconfig.
# Preparing to unpack .../13-fontconfig_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking fontconfig (2.13.1-2ubuntu3) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libann0.
# Preparing to unpack .../14-libann0_1.1.2+doc-7build1_amd64.deb ...
# Unpacking libann0 (1.1.2+doc-7build1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libcdt5:amd64.
# Preparing to unpack .../15-libcdt5_2.42.2-3build2_amd64.deb ...
# Unpacking libcdt5:amd64 (2.42.2-3build2) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libcgraph6:amd64.
# Preparing to unpack .../16-libcgraph6_2.42.2-3build2_amd64.deb ...
# Unpacking libcgraph6:amd64 (2.42.2-3build2) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../17-libjbig0_2.1-3.1build1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1build1) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libwebp6:amd64.
# Preparing to unpack .../18-libwebp6_0.6.1-2ubuntu0.20.04.1_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.1-2ubuntu0.20.04.1) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../19-libtiff5_4.1.0+git191117-2ubuntu0.20.04.2_amd64.deb ...
# Unpacking libtiff5:amd64 (4.1.0+git191117-2ubuntu0.20.04.2) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libxpm4:amd64.
# Preparing to unpack .../20-libxpm4_1%3a3.5.12-1_amd64.deb ...
# Unpacking libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libgd3:amd64.
# Preparing to unpack .../21-libgd3_2.2.5-5.2ubuntu2.1_amd64.deb ...
# Unpacking libgd3:amd64 (2.2.5-5.2ubuntu2.1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libgts-0.7-5:amd64.
# Preparing to unpack .../22-libgts-0.7-5_0.7.6+darcs121130-4_amd64.deb ...
# Unpacking libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../23-libpixman-1-0_0.38.4-0ubuntu1_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.38.4-0ubuntu1) ...
# 7Progress: [ 24%] [##############............................................] 8Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../24-libxcb-render0_1.14-2_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.14-2) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../25-libxcb-shm0_1.14-2_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.14-2) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libxrender1:amd64.
# Preparing to unpack .../26-libxrender1_1%3a0.9.10-1_amd64.deb ...
# Unpacking libxrender1:amd64 (1:0.9.10-1) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../27-libcairo2_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo2:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libltdl7:amd64.
# Preparing to unpack .../28-libltdl7_2.4.6-14_amd64.deb ...
# Unpacking libltdl7:amd64 (2.4.6-14) ...
# 7Progress: [ 29%] [#################.........................................] 8Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../29-libgraphite2-3_1.3.13-11build1_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.13-11build1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../30-libharfbuzz0b_2.6.4-1ubuntu4_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (2.6.4-1ubuntu4) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libthai-data.
# Preparing to unpack .../31-libthai-data_0.1.28-3_all.deb ...
# Unpacking libthai-data (0.1.28-3) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../32-libdatrie1_0.2.12-3_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.12-3) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../33-libthai0_0.1.28-3_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libthai0:amd64 (0.1.28-3) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../34-libpango-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libpango-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../35-libpangoft2-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libpangoft2-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../36-libpangocairo-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libpangocairo-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package libpathplan4:amd64.
# Preparing to unpack .../37-libpathplan4_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libpathplan4:amd64 (2.42.2-3build2) ...
# Selecting previously unselected package libgvc6.
# Preparing to unpack .../38-libgvc6_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libgvc6 (2.42.2-3build2) ...
# Selecting previously unselected package libgvpr2:amd64.
# Preparing to unpack .../39-libgvpr2_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libgvpr2:amd64 (2.42.2-3build2) ...
# Selecting previously unselected package liblab-gamut1:amd64.
# Preparing to unpack .../40-liblab-gamut1_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking liblab-gamut1:amd64 (2.42.2-3build2) ...
# Selecting previously unselected package x11-common.
# Preparing to unpack .../41-x11-common_1%3a7.7+19ubuntu14_all.deb ...
# 7Progress: [ 42%] [########################..................................] 8dpkg-query: no packages found matching nux-tools
# Unpacking x11-common (1:7.7+19ubuntu14) ...
# Selecting previously unselected package libice6:amd64.
# Preparing to unpack .../42-libice6_2%3a1.0.10-0ubuntu1_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking libice6:amd64 (2:1.0.10-0ubuntu1) ...
# Selecting previously unselected package libsm6:amd64.
# Preparing to unpack .../43-libsm6_2%3a1.2.3-1_amd64.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking libsm6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../44-libxt6_1%3a1.1.5-1_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking libxt6:amd64 (1:1.1.5-1) ...
# Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../45-libxmu6_2%3a1.1.3-0ubuntu1_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libxmu6:amd64 (2:1.1.3-0ubuntu1) ...
# Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../46-libxaw7_2%3a1.0.13-1_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libxaw7:amd64 (2:1.0.13-1) ...
# Selecting previously unselected package graphviz.
# Preparing to unpack .../47-graphviz_2.42.2-3build2_amd64.deb ...
# 7Progress: [ 48%] [###########################...............................] 8Unpacking graphviz (2.42.2-3build2) ...
# Selecting previously unselected package libgts-bin.
# Preparing to unpack .../48-libgts-bin_0.7.6+darcs121130-4_amd64.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking libgts-bin (0.7.6+darcs121130-4) ...
# Setting up libgraphite2-3:amd64 (1.3.13-11build1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libpixman-1-0:amd64 (0.38.4-0ubuntu1) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libxau6:amd64 (1:1.0.9-0ubuntu1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libdatrie1:amd64 (0.2.12-3) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up liblab-gamut1:amd64 (2.42.2-3build2) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up x11-common (1:7.7+19ubuntu14) ...
# 7Progress: [ 55%] [################################..........................] 8update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libjbig0:amd64 (2.1-3.1build1) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libx11-data (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libpathplan4:amd64 (2.42.2-3build2) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libann0 (1.1.2+doc-7build1) ...
# 7Progress: [ 60%] [###################################.......................] 8Setting up libfribidi0:amd64 (1.0.8-2) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libwebp6:amd64 (0.6.1-2ubuntu0.20.04.1) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up fonts-dejavu-core (2.37-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up ucf (3.0038+nmu1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libltdl7:amd64 (2.4.6-14) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up fonts-liberation (1:1.07.4-11) ...
# 7Progress: [ 66%] [######################################....................] 87Progress: [ 67%] [######################################....................] 8Setting up libharfbuzz0b:amd64 (2.6.4-1ubuntu4) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libthai-data (0.1.28-3) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libcdt5:amd64 (2.42.2-3build2) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libcgraph6:amd64 (2.42.2-3build2) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libtiff5:amd64 (4.1.0+git191117-2ubuntu0.20.04.2) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libbsd0:amd64 (0.10.0-1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libgts-bin (0.7.6+darcs121130-4) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libice6:amd64 (2:1.0.10-0ubuntu1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libxdmcp6:amd64 (1:1.1.3-0ubuntu1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libxcb1:amd64 (1.14-2) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libxcb-render0:amd64 (1.14-2) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up fontconfig-config (2.13.1-2ubuntu3) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libxcb-shm0:amd64 (1.14-2) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libthai0:amd64 (0.1.28-3) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libgvpr2:amd64 (2.42.2-3build2) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libx11-6:amd64 (2:1.6.9-2ubuntu1.2) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libfontconfig1:amd64 (2.13.1-2ubuntu3) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libsm6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up fontconfig (2.13.1-2ubuntu3) ...
# Regenerating fonts cache... done.
# 7Progress: [ 86%] [##################################################........] 8Setting up libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libxrender1:amd64 (1:0.9.10-1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libpango-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libxext6:amd64 (2:1.3.4-0ubuntu1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libcairo2:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libgd3:amd64 (2.2.5-5.2ubuntu2.1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libpangoft2-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libpangocairo-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libxmu6:amd64 (2:1.1.3-0ubuntu1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libgvc6 (2.42.2-3build2) ...
# 7Progress: [ 98%] [#########################################################.] 8Setting up graphviz (2.42.2-3build2) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for systemd (245.4-4ubuntu3.13) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.2) ...
#
# 78

# %%
# !pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot) (2.4.7)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
input = Input(shape=(100, ), dtype  ='int32', name='input')
x = Embedding(output_dim=512, input_dim=10000, input_length=100)(input)
x = LSTM(32)(x)
x = Dense(64, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x= Dense(64, activation='relu')(x)
output = Dense(1, activation='sigmoid', name='output')(x)
model = Model(inputs=[input], outputs=[output])
dot_image_file='/tmp/model.png'
plot_model(model, to_file=dot_image_file, show_shapes=True)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5076485052999584624
#  xla_global_id: -1]
